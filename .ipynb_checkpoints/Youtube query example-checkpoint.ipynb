# %% [markdown]
# In this notebook we document an attempt to use Google's Youtube api for the first time. We will try to obtain some simple attributes for a target video on youtube: e.g. View Count, Video name, Thumbs up, Channel name.

# %% [markdown]
# Youtube has a getting started page for developers at :
# https://developers.google.com/youtube/v3/getting-started
#
# There's a decent tutorial for getting some youtube data here:
# https://medium.com/greyatom/youtube-data-in-python-6147160c5833

# %% [markdown]
# We'll start by downloading the right packages for python:
#
# Input into cmd: conda install -c conda-forge google-api-python-client
#
# You might need to restart the ipynb kernal a few times or run the conda command a few times to make sure everything actually got installed.
#
# This should get the googleapi packages and their dependencies.

# %% [markdown]
# Here's an example request that is a youtube search, taken from the above tutorial:
# (There's some things that I'd do differently if I rewrote it - I'd make sure it was clear we've retrieved everything from this query and I'd also do the variable typing as they are read from the response.

# %%
from apiclient.discovery import build
# from apiclient.errors import HttpError
# from oauth2client.tools import argparser
import pandas as pd
import pprint 
import matplotlib.pyplot as plt
import os

apikey_path = os.path.join(os.path.join(os.getcwd(),os.pardir),"apikey.txt")

with open(apikey_path,"rb") as f:
    apikey = f.readline()

DEVELOPER_KEY = apikey
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def youtube_search(q, max_results=50,order="relevance", token=None, location=None, location_radius=None):

    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

    search_response = youtube.search().list(
    q=q,
    type="video",
    pageToken=token,
    order = order,
    part="id,snippet", # Part signifies the different types of data you want 
    maxResults=max_results,
    location=location,
    locationRadius=location_radius).execute()

    title = []
    channelId = []
    channelTitle = []
    categoryId = []
    videoId = []
    viewCount = []
    likeCount = []
    dislikeCount = []
    commentCount = []
    favoriteCount = []
    category = []
    tags = []
    videos = []
    
    
    for search_result in search_response.get("items", []):
        if search_result["id"]["kind"] == "youtube#video":

            title.append(search_result['snippet']['title']) 

            videoId.append(search_result['id']['videoId'])

            response = youtube.videos().list(
                part='statistics, snippet',
                id=search_result['id']['videoId']).execute()

            channelId.append(response['items'][0]['snippet']['channelId'])
            channelTitle.append(response['items'][0]['snippet']['channelTitle'])
            categoryId.append(response['items'][0]['snippet']['categoryId'])
            favoriteCount.append(response['items'][0]['statistics']['favoriteCount'])
            viewCount.append(response['items'][0]['statistics']['viewCount'])
            likeCount.append(response['items'][0]['statistics']['likeCount'])
            dislikeCount.append(response['items'][0]['statistics']['dislikeCount'])
 
        if 'commentCount' in response['items'][0]['statistics'].keys():
            commentCount.append(response['items'][0]['statistics']['commentCount'])
        else:
            commentCount.append([])
  
        if 'tags' in response['items'][0]['snippet'].keys():
            tags.append(response['items'][0]['snippet']['tags'])
        else:
            tags.append([])
    
    
    youtube_dict = {'tags':tags,'channelId': channelId,'channelTitle': channelTitle,'categoryId':categoryId,'title':title,'videoId':videoId,'viewCount':viewCount,'likeCount':likeCount,'dislikeCount':dislikeCount,'commentCount':commentCount,'favoriteCount':favoriteCount}

    return youtube_dict

# %% [markdown]
# Using this function we can get the first 50 results for a search

# %%
A = youtube_search("h3h3")

# %% [markdown]
# A now contains the 50 top results for the search term "h3h3", which should return the work of Ethan Klein, a popular YouTube videoblogger. A is a dictionary, by construction, and allows easy importation into a dataframe format using pandas.

# %%
import pandas as pd
import pprint 
import matplotlib.pyplot as plt

Adf = pd.DataFrame(A)
Adf["viewCount"] = pd.to_numeric(Adf["viewCount"])
Adf["likeCount"] = pd.to_numeric(Adf["likeCount"])
Adf["dislikeCount"] = pd.to_numeric(Adf["dislikeCount"])
Adf["ControversyIndex"] = Adf["dislikeCount"]/(Adf["dislikeCount"]+Adf["likeCount"])

# %% [markdown]
# Currently we have a problem, the data types in our dataframe are all unicode strings (ideally, we would declare types when importing).

# %%
Adf_VC_sort = Adf.sort_values(by=['viewCount'], ascending=False)
Adf_Controv_sort = Adf.sort_values(by=["ControversyIndex"], ascending=False)

Adf_Controv_sort
# Out:
#    categoryId                 channelId           channelTitle commentCount  \
# 49         22  UCZZHPXsg6LopvdOKF7qM6cQ  H3 Podcast Highlights         5358
# 20         22  UCZZHPXsg6LopvdOKF7qM6cQ  H3 Podcast Highlights         7015
# 8          22  UCZZHPXsg6LopvdOKF7qM6cQ  H3 Podcast Highlights        10514
# 41         24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast        11694
# 3          24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        10848
# 28         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        17575
# 12         22  UCZZHPXsg6LopvdOKF7qM6cQ  H3 Podcast Highlights         6276
# 10         22  UCZZHPXsg6LopvdOKF7qM6cQ  H3 Podcast Highlights         2397
# 25         24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast         5515
# 13         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        39106
# 1          24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast         4472
# 19         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        14468
# 33         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        39927
# 5          24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        25256
# 30         24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast        12944
# 26         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        33287
# 36         24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast         5482
# 45         22  UCZZHPXsg6LopvdOKF7qM6cQ  H3 Podcast Highlights         4126
# 9          24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        41522
# 32         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions         9935
# 40         24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast        13330
# 37         24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast         3380
# 14         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        25087
# 44         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        40089
# 47         22  UCZZHPXsg6LopvdOKF7qM6cQ  H3 Podcast Highlights         1789
# 16         24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast         9709
# 21         24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast        12250
# 43         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        29783
# 6          24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        25009
# 15         22  UCZZHPXsg6LopvdOKF7qM6cQ  H3 Podcast Highlights          867
# 17         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        19191
# 4          24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast         4941
# 24         23  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        17674
# 48         23  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        19030
# 38         23  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions         7269
# 7          24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        15524
# 22         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        28613
# 0          24  UCLtREJY21xRfCuEKvdki1Kw             H3 Podcast         3664
# 34         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        40071
# 42         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        23049
# 2          24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions         5299
# 27         23  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions         9125
# 46         23  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions         5369
# 11         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        21530
# 39         26  UCPD_bxCRGpmmeQcbe2kpPaA         First We Feast        15248
# 18         24  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        13841
# 31         23  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions        15440
# 35         22  UCZZHPXsg6LopvdOKF7qM6cQ  H3 Podcast Highlights          122
# 23         23  UCDWIvJwLJsE4LG1Atne2blQ        h3h3Productions         5101
# 29         22  UCZZHPXsg6LopvdOKF7qM6cQ  H3 Podcast Highlights          248
#
#     dislikeCount favoriteCount  likeCount  \
# 49          1522             0      16613
# 20          1520             0      21781
# 8           5512             0      79292
# 41          4194             0      60646
# 3           8686             0     143769
# 28         13540             0     248347
# 12          1440             0      27807
# 10           835             0      18267
# 25          1050             0      23050
# 13         18780             0     413395
# 1            785             0      20631
# 19          6795             0     183814
# 33         13830             0     419417
# 5           7834             0     242969
# 30          2822             0      93171
# 26          8633             0     292164
# 36          1553             0      52950
# 45           708             0      24189
# 9          11705             0     413301
# 32          4477             0     159137
# 40          2487             0      90226
# 37           487             0      18494
# 14          5883             0     226810
# 44          7859             0     306449
# 47           435             0      17710
# 16          1553             0      63895
# 21          2037             0      89148
# 43          8064             0     356369
# 6           6487             0     294633
# 15           214             0       9811
# 17          7943             0     369311
# 4            933             0      43772
# 24          3000             0     150910
# 48          6106             0     316366
# 38          1558             0      86378
# 7           3282             0     187028
# 22          9340             0     544236
# 0            489             0      28605
# 34          4173             0     254523
# 42          3634             0     266597
# 2            861             0      64609
# 27          1392             0     107557
# 46          1207             0      93601
# 11          4024             0     312949
# 39          2833             0     242616
# 18          2299             0     198012
# 31          2028             0     176452
# 35             7             0        653
# 23           618             0      84823
# 29            13             0       2079
#
#                                                  tags  \
# 49  [h3 podcast, podcast, h3h3, h3h3productions, e...
# 20  [h3 podcast, podcast, h3h3, h3h3productions, e...
# 8   [h3 podcast, podcast, h3h3, h3h3productions, e...
# 41  [jontron, jon tron, jon, tron, jon jafari, jaf...
# 3   [facebook, mark zuckerberg, ethans corner, h3h...
# 28  [human mail challenge, human, mail, challenge,...
# 12  [h3 podcast, podcast, h3h3, h3h3productions, e...
# 10  [h3 podcast, podcast, h3h3, h3h3productions, e...
# 25  [h3 podcast, h3h3 podcast, h3h3, h3h3productio...
# 13  [net neutrality, net, neutrality, ajit pai, aj...
# 1   [deadmau5, joel zimmerman, podcast, h3h3 podca...
# 19  [mark zuckerberg, mark, zuckerberg, facebook, ...
# 33  [jake, jake paul, jakepaulers, paul, its, ever...
# 5   [words you cant say anymore, the m word, now t...
# 30  [jordan peterson, jordan, peterson, jordanbpet...
# 26  [where have we been?, where has h3h3 been, h3h...
# 36  [dr disrespect, drdisrespect, dr, disrespect, ...
# 45  [h3 podcast, podcast, h3h3, h3h3productions, e...
# 9   [logan, paul, logan paul, maverick, be a maver...
# 32  [payday, payday 2, h3h3 dlc, dlc, h3h3 dlc pac...
# 40  [dunkey, videogamedunkey, video, game, videoga...
# 37  [bob saget, bob, saget, h3h3 podcast, h3 podca...
# 14  [cryptocurrency, bitcoin, bit coin, bitconnect...
# 44  [jake paul, jake, paul, ktla, LA, los angeles,...
# 47  [h3 podcast, podcast, h3h3, h3h3productions, e...
# 16  [shane dawson, shane, dawson, shanedawsontv, s...
# 21  [post malone, post, malone, h3 podcast, podcas...
# 43  [lance stewart, lance, stewart, instagram, vin...
# 6   [prankinvasion, prank invasion, a closer look,...
# 15  [h3 podcast, podcast, h3h3, h3h3productions, e...
# 17  [my new vape, new vape, 148 batteries, 150 bat...
# 4   [post malone, post, malone, h3h3 podcast, podc...
# 24  [h3h3productions, psychic, medium, hypnotist, ...
# 48  [Homelessness (Film Subject), feeding the home...
# 38  [nature valley, nature, technology, look up, g...
# 7   [dumb products, stupid products, products, the...
# 22  [jimmy kimmel, jimmy, kimmel, casey, neistat, ...
# 0   [hot ones, first we feast, fwf, firstwefeast, ...
# 34  [skippy, fun single ready to mingle, fun, sing...
# 42  [buzzfeed, buzz, feed, buzzfeedvideo, h3h3, h3...
# 2              [askh3, ask h3, h3h3productions, h3h3]
# 27  [game crazy, video games, gaming, retro, h3h3 ...
# 46  [rap, hip, hop, Hip Hop Music (Musical Genre),...
# 11  [educational, education, educational video, ed...
# 39  [First we feast, fwf, firstwefeast, food, food...
# 18  [technology, invention, smart tech, hushme, VR...
# 31  [h3h3productions, youtube, the greatest youtub...
# 35  [h3 podcast, podcast, h3h3, h3h3productions, e...
# 23  [expertvillage, expert, village, tutorials, eh...
# 29  [h3 podcast, podcast, h3h3, h3h3productions, e...
#
#                                                 title      videoId  viewCount  \
# 49                           H3H3 On Elon Musk Haters  S-BA4PRUVMU     592609
# 20               H3H3 On the Biggest Idiot On Youtube  MgLO_ojVcJ8     976344
# 8                          H3H3 Slams Ellen DeGeneres  YuZxT89-GDk    2682618
# 41                           H3 Podcast #41 - JonTron  irVe0wQkMXg    2043603
# 3                           Ethan's Corner - Facebook  vb97DrNDSfM    1759749
# 28                 The Human Mail Challenge is Stupid  XvYDPHEJ9Rg    5089338
# 12                  H3H3 On Logan Paul Demonetization  386gkrAKKC4    1152948
# 10                                  H3H3 On Deepfakes  HqjKn0iC6l8    1146329
# 25  H3 Podcast #53 - Female Teacher Sleeps w Stude...  sUyR_nz-JsA    1115107
# 13                         It's Time To Stop Ajit Pai  5uXsCaakZD8    5732701
# 1                           H3 Podcast #59 - Deadmau5  WEMAvnkHA9U     639033
# 19    Mark Zuckerberg's VR Safari Through Puerto Rico  _HEjlT8DWqg    2827155
# 33            Sit Down Jake Paul (It's Every Day Bro)  ybCeaYsrM6s    9228891
# 5                         The Return of Whiteface Man  zlAqizx7Lf0    3817527
# 30                   H3 Podcast #37 - Jordan Peterson  vx4ltQhdlhg    2367834
# 26                                Where have we been?  I5uXtODq74w    3818700
# 36                     H3 Podcast #36 - Dr Disrespect  I9hL4zQy0UI    1911792
# 45  H3H3 Watches Megachurch Pastor Explain Why He ...  PiJE3XPu1XA     958928
# 9                              The Logan Paul Odyssey  N3Dlpky9ey8    6322636
# 32                                WE'RE IN PAYDAY 2!!  -OProdXkbYQ    3089052
# 40            H3 Podcast #34 - VideoGameDunkey & Leah  ph5FR-RFhbg    3028864
# 37                         H3 Podcast #57 - Bob Saget  D4JrLoUhHPA     572741
# 14   How To Lose Your Life's Savings w Cryptocurrency  EhL2OWXZ26s    4582401
# 44                        Jake Paul Ruins Los Angeles  8D3uG0u2__o    5719180
# 47             H3H3 On Being Baited By Prank Invasion  6K730j6GzIY     887088
# 16                      H3 Podcast #52 - Shane Dawson  VXvblzAs6vM    1567808
# 21                       H3 Podcast #39 - Post Malone  tr1Loa7r7sY    3319367
# 43                    It's Time to Stop Lance Stewart  kNVf6_BjzjM    7820702
# 6                       Prank Invasion: A Closer Look  SV1ho61qaG4    4023959
# 15  H3H3 Reacts To Jake Paul's All I Want For Chri...  Rskjh1ZfQww     453725
# 17                  Insane VAPE MOD w/ 150 BATTERIES!  3C2OUQL6_yQ    5911601
# 4   H3 Podcast #56 - Post Malone Live From The Hol...  CU8q0rX0Y-Y    1264308
# 24  Psychics, Mediums, and Gurus -- h3h3 reaction ...  EBbLPnQ-CEw    5217470
# 48        Feeding the Homeless -- h3h3 reaction video  W_qePqppbdQ   11246225
# 38  Nature Valley Rediscover Nature -- h3h3 reacti...  LUHQnZUDh3I    3344264
# 7                    The Dumbest Products Of All Time  wLjza0c-ykQ    3939609
# 22            YouTube's Rules Don't Apply to Everyone  pj8n78AuN3w    6752153
# 0             H3 Podcast #58 - Sean Evans of Hot Ones  ecrM2MqNlAM    1024707
# 34                   The Real Life 34 Year Old Virgin  WXEdJX78L0I    6268453
# 42               BuzzFeed: The McDonald's of Feminism  8cgFrX0Y8TE    5052910
# 2                      Hila's Biggest Regret (#askh3)  iL_wGOJAvC4     775320
# 27   Game Crazy Training Video -- h3h3 reaction video  YJJN-8Y0BP4    3628000
# 46                  The Rapper -- h3h3 reaction video  mCYChsmqgYU    4781087
# 11                    "Educational" Videos on YouTube  f_F0ZZbcugc    5628929
# 39  H3H3 Productions Does Couples Therapy While Ea...  Tgw2Kkmupg8    6094692
# 18   Ethan Becomes an Inventor -- h3h3 reaction video  ipQKBwQxoeQ    3789594
# 31  The Greatest YouTuber of ALL TIME -- h3h3 reac...  VjLI-vvuLcc    5698521
# 35            H3H3 On Performing With A Live Audience  QL1au3oC24A       5940
# 23                ExpertVillage - h3h3 reaction video  JV9XUp5Rmws    3936805
# 29                Bobby Lee and H3H3 Roast Each Other  nwUjdmdsRQc      32990
#
#     ControversyIndex
# 49          0.083926
# 20          0.065233
# 8           0.064997
# 41          0.064682
# 3           0.056974
# 28          0.051702
# 12          0.049236
# 10          0.043713
# 25          0.043568
# 13          0.043455
# 1           0.036655
# 19          0.035649
# 33          0.031922
# 5           0.031236
# 30          0.029398
# 26          0.028700
# 36          0.028494
# 45          0.028437
# 9           0.027541
# 32          0.027363
# 40          0.026825
# 37          0.025657
# 14          0.025282
# 44          0.025004
# 47          0.023974
# 16          0.023729
# 21          0.022339
# 43          0.022128
# 6           0.021543
# 15          0.021347
# 17          0.021055
# 4           0.020870
# 24          0.019492
# 48          0.018935
# 38          0.017717
# 7           0.017246
# 22          0.016872
# 0           0.016808
# 34          0.016131
# 42          0.013448
# 2           0.013151
# 27          0.012777
# 46          0.012731
# 11          0.012695
# 39          0.011542
# 18          0.011477
# 31          0.011363
# 35          0.010606
# 23          0.007233
# 29          0.006214

# %% [markdown]
# We invented a metric called Controversy Index, which is the ratio of thumbs down to all thumbs.

# %%
with open("C:/Users/AI/Documents/Projects/Python/Notebooks/apikey.txt","rb") as f:
    print f.readline()
# Out:
# AIzaSyDYEubHdR-SolXXyXdCbCF1ivVL5sy8k3c

# %%
import os
print os.path.join(os.path.join(os.getcwd(),os.pardir),"apikey.txt")
# Out:
# C:\Users\AI\Documents\Projects\Python\Notebooks\Google API\..\apikey.txt
